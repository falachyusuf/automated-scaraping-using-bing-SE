# %% [markdown]
# Create a folder to save the images

# %%
# !mkdir dataset_konservasi
# Out:
# mkdir: cannot create directory ‘dataset_konservasi’: File exists

# %% [markdown]
# Install library bing-image-downloader

# %%
# !pip install bing-image-downloader

# %% [markdown]
# This is the script for scraping the file

# %%
from bing_image_downloader import downloader

downloader.download('insang ikan nila segar', limit=150, output_dir='dataset_konservasi', adult_filter_off = True)
# Out:
# [%] Downloading Images to /content/dataset_konservasi/insang ikan nila segar
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/46/6e/94/466e94e2fd240b4c7e3e2843f4163910.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://nilabekasi.files.wordpress.com/2014/10/budidaya-ikan-nila-gesit1.jpg?w=1200
# [!] Issue getting: https://nilabekasi.files.wordpress.com/2014/10/budidaya-ikan-nila-gesit1.jpg?w=1200
# [!] Error:: The read operation timed out
# [%] Downloading Image #2 from https://gdmagri.com/wp-content/uploads/2020/06/Ikan-nila-gesit.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://gdmagri.com/wp-content/uploads/2020/06/ikan-nila-1024x600.jpg
# [%] File Downloaded !
#
# ...

# %% [markdown]
# Zip all the downloaded file

# %%
# !zip -r '/content/dataset_konservasi.zip' '/content/dataset_konservasi'
# Out:
#   adding: content/dataset_konservasi/ (stored 0%)
#   adding: content/dataset_konservasi/insang ikan nila segar/ (stored 0%)
#   adding: content/dataset_konservasi/insang ikan nila segar/Image_79.jpg (deflated 0%)
#   adding: content/dataset_konservasi/insang ikan nila segar/Image_78.jpg (deflated 0%)
#   adding: content/dataset_konservasi/insang ikan nila segar/Image_50.jpg (deflated 0%)
#   adding: content/dataset_konservasi/insang ikan nila segar/Image_32.jpg (deflated 0%)
#   adding: content/dataset_konservasi/insang ikan nila segar/Image_4.jpg (deflated 0%)
#   adding: content/dataset_konservasi/insang ikan nila segar/Image_141.jpg (deflated 0%)
#   adding: content/dataset_konservasi/insang ikan nila segar/Image_68.jpg (deflated 0%)
#   adding: content/dataset_konservasi/insang ikan nila segar/Image_119.jpg (deflated 2%)
#   adding: content/dataset_konservasi/insang ikan nila segar/Image_82.jpg (deflated 0%)
# ...

# %% [markdown]
# Remove the folder if already finish

# %%
import shutil

folder_to_remove = '/content/dataset_konservasi'  # Replace with the path to the folder you want to remove

# Use shutil.rmtree to remove the folder and its contents
shutil.rmtree(folder_to_remove)

print(f"Folder '{folder_to_remove}' has been removed.")
# Out:
# Folder '/content/dataset_konservasi' has been removed.
